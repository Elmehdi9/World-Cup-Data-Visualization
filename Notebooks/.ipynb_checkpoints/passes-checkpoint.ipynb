# %% [markdown]
# ### Visualization: Passes
# <h5>Notebook Brief:</h5>
#
# In this notebook, I attempt to visualize and get insights out of passes data of the World Cup 2022.
#
# <h5>Workflow (Steps):</h5>
#
# - Dembele's two footdness
# - Passing network

# %% [markdown]
# Imports

# %%
from statsbombpy import sb
import pandas as pd
import numpy as np

import seaborn as sn 
import matplotlib.pyplot as plt
from mplsoccer import Pitch, FontManager, VerticalPitch

import warnings
warnings.filterwarnings('ignore')
font_bold = FontManager('https://raw.githubusercontent.com/google/fonts/main/apache/robotoslab/'
                        'RobotoSlab%5Bwght%5D.ttf')
font_italic = FontManager('https://raw.githubusercontent.com/google/fonts/main/apache/roboto/'
                          'Roboto-Italic%5Bwdth,wght%5D.ttf')

# %%
df_comps=  sb.competitions()

# Get competition and season ids 
df_comps[(df_comps.competition_name== 'FIFA World Cup') & (df_comps.season_name== '2022')]
# Out:
#     competition_id  season_id   country_name competition_name  \
# 18              43        106  International   FIFA World Cup
#
#    competition_gender  competition_youth  competition_international  \
# 18               male              False                       True
#
#    season_name               match_updated           match_updated_360  \
# 18        2022  2023-02-03T13:22:36.184520  2023-01-26T11:23:27.631134
#
#            match_available_360             match_available
# 18  2023-01-26T11:23:27.631134  2023-02-03T13:22:36.184520

# %%
grouped_events = sb.competition_events(
    country="International",
    division= "FIFA World Cup",
    season="2022",
    split=True
)

# %%
passes_df= grouped_events["passes"]
passes_df.head(2)
# Out:
#                                      id  index  period     timestamp  minute  \
# 0  dd7183e3-e7ab-47d4-9035-5e827f351c88      5       1  00:00:00.812       0
# 1  ac155851-e1ff-421f-8e93-f197b8020239      9       1  00:00:02.747       0
#
#    second  type  possession possession_team   play_pattern  ... counterpress  \
# 0       0  Pass           2     Netherlands  From Kick Off  ...          NaN
# 1       2  Pass           2     Netherlands  From Kick Off  ...          NaN
#
#   pass_cross pass_deflected pass_cut_back  pass_outswinging  \
# 0        NaN            NaN           NaN               NaN
# 1        NaN            NaN           NaN               NaN
#
#   pass_miscommunication  pass_inswinging pass_goal_assist  out  pass_straight
# 0                   NaN              NaN              NaN  NaN            NaN
# 1                   NaN              NaN              NaN  NaN            NaN
#
# [2 rows x 46 columns]

# %% [markdown]
# 1. Dembele's two footdness plot

# %%
# Split location column into start_X and start_Y columns
passes_df[['start_X', 'start_Y']] = pd.DataFrame(passes_df['location'].to_list(), index= passes_df.index)
passes_df[['end_X', 'end_Y']]= pd.DataFrame(passes_df['pass_end_location'].to_list(), index= passes_df.index)

# Filter passes
passes_df= passes_df.loc[passes_df.play_pattern.isin(['Regular Play', 'From Counter', 'From Free Kick'])]
ousmane_df= passes_df.loc[(passes_df.player== 'Ousmane Dembélé') & 
                          (passes_df.pass_body_part.isin(('Right Foot', 'Left Foot')))]
ousmane_df
# Out:
#                                          id  index  period     timestamp  \
# 6299   9dac35d3-5302-4e55-8c1e-559dfa14d864    254       1  00:06:01.447
# 6307   a7505965-30e2-401c-9ce7-e3c6cacc800c    278       1  00:06:33.099
# 6356   f8703392-f8e5-446e-a151-0ca99ab2418f    453       1  00:12:58.738
# 6374   ce7dc5a4-d8e4-47cc-b1b2-28bfa3f86999    509       1  00:14:32.354
# 6480   4a8eb20a-f868-40df-90d2-22b3b870161b    852       1  00:25:31.101
# ...                                     ...    ...     ...           ...
# 54916  3180489a-03a0-4582-bf73-139ebced44a2   3093       2  00:40:10.808
# 54938  f97661a5-8ad0-42d9-9039-d36139373b5a   3170       2  00:42:39.974
# 54973  598b4111-6d54-4b1b-8f60-6a1d5d7cc074   3288       2  00:45:54.268
# 54998  5c805a87-2234-40df-872d-dd553b250ba4   3383       2  00:49:07.452
# 55027  b09cded5-93f2-47fb-9df5-221f63625bdf   3486       2  00:52:05.073
#
#        minute  second  type  possession possession_team    play_pattern  ...  \
# 6299        6       1  Pass          16          France  From Free Kick  ...
# 6307        6      33  Pass          16          France  From Free Kick  ...
# 6356       12      58  Pass          22          France  From Free Kick  ...
# 6374       14      32  Pass          24          France  From Free Kick  ...
# 6480       25      31  Pass          39       Argentina    Regular Play  ...
# ...       ...     ...   ...         ...             ...             ...  ...
# 54916      85      10  Pass         163          France    Regular Play  ...
# 54938      87      39  Pass         168          France    Regular Play  ...
# 54973      90      54  Pass         173          France    Regular Play  ...
# 54998      94       7  Pass         177          France  From Free Kick  ...
# 55027      97       5  Pass         184          France    Regular Play  ...
#
#       pass_outswinging pass_miscommunication pass_inswinging pass_goal_assist  \
# 6299               NaN                   NaN             NaN              NaN
# 6307               NaN                   NaN             NaN              NaN
# 6356               NaN                   NaN             NaN              NaN
# 6374               NaN                   NaN             NaN              NaN
# 6480               NaN                   NaN             NaN              NaN
# ...                ...                   ...             ...              ...
# 54916              NaN                   NaN             NaN              NaN
# 54938              NaN                   NaN             NaN              NaN
# 54973              NaN                   NaN             NaN              NaN
# 54998              NaN                   NaN             NaN              NaN
# 55027              NaN                   NaN             NaN              NaN
#
#        out pass_straight  start_X start_Y  end_X  end_Y
# 6299   NaN           NaN     64.6    76.1   44.1   71.4
# 6307   NaN           NaN     52.2    66.7   45.8   60.5
# 6356   NaN           NaN     90.3    66.3   93.3   19.2
# 6374   NaN           NaN     89.5    75.9   80.0   74.4
# 6480   NaN           NaN     80.3    70.8   88.8   56.2
# ...    ...           ...      ...     ...    ...    ...
# 54916  NaN           NaN     55.8    70.4   56.6   66.4
# 54938  NaN           NaN    103.8    58.4   94.4   27.6
# 54973  NaN           NaN     70.6    61.2   58.8   54.4
# 54998  NaN           NaN    101.9    70.6  108.8   34.6
# 55027  NaN           NaN     96.9    51.8   86.2   52.3
#
# [118 rows x 50 columns]

# %%
# Set pitches
pitch = Pitch(pitch_type= 'statsbomb',pad_bottom=0.5, goal_alpha=1,
                      pitch_color= 'white', line_color='black', linewidth=.3) 
fig, ax= pitch.grid(ncols= 2, grid_height= .75, space= .05, axis= False)

X= list(ousmane_df.start_X)
Y= list(ousmane_df.start_Y)
end_X= list(ousmane_df.end_X)
end_Y= list(ousmane_df.end_Y)
foot= list(ousmane_df.pass_body_part)


for i in range(len(X)):
    if foot[i]=='Right Foot':
        ax['pitch'][0].scatter(end_X[i], end_Y[i],color="#8B0000")
        pitch.arrows(X[i], Y[i], end_X[i], end_Y[i], color = "#8B0000", width=1.2, headwidth= 0, ax=ax['pitch'][0])
    else:
        ax['pitch'][1].scatter(end_X[i], end_Y[i],color="#8B0000")
        pitch.arrows(X[i], Y[i], end_X[i], end_Y[i], color = "#8B0000", width=1.2, headwidth= 0, ax=ax['pitch'][1])

ax['pitch'][0].set_title(label="Right Foot", loc='left',x= .04, fontweight='bold', fontsize= 16)
ax['pitch'][1].set_title(label="Left Foot", loc='left',x= .04, fontweight='bold', fontsize= 16)



# Set titles
title_text= "Ousmane Dembélé Pass Footdness"
subtitle= "FIFA World Cup 2022"
Description= 'Created by @dahb_elmehdi, data provided by StatsBomb'

# Add titles
fig.text(0.04, .97, title_text, fontsize=34, fontweight= 'bold', color='black')
fig.text(0.04, .92, subtitle, fontsize=20, color='black',fontproperties= font_bold.prop,alpha=.4)
fig.text(0.04, .04, Description, fontsize=13, color='black',fontproperties= font_italic.prop)


# Save the graph
fig.savefig("../Plots/passes-1.png", dpi= 150, bbox_inches='tight')

# %% [markdown]
# 2. Passing network
#
# To create a pass network, we must first gather information about player positioning and amount of passes. These details can be summarized as follows:
# - Average player locations
# - Number of passes between players
# - Color and fifth line are determined by the number of connections and passes made by participants.

# %%
# First let's import events data of the World Cup final
df= sb.matches(competition_id=43, season_id=106)
df= int(df.loc[df.competition_stage== 'Final'].match_id.values)
events = sb.events(match_id=final_id)

first_sub= events.loc[(events.type== 'Substitution') & (events.team== 'Argentina' )].minute.min()
DF= events.loc[(~events.pass_outcome.isin(['Out', 'Incomplete', 'Unknown', 'Pass Offside'])) & (events.team== 'Argentina' ) &
              (events.type=='Pass') & (events.minute< first_sub)]

DF[['start_X', 'start_Y']] = pd.DataFrame(DF['location'].to_list(), index= DF.index)
DF[['end_X', 'end_Y']]= pd.DataFrame(DF['pass_end_location'].to_list(), index= DF.index)

# Average locations 
avg_locations= DF.groupby('player').agg({'start_X':['mean', 'count'], 'start_Y': 'mean'})
#Rename columns
avg_locations.columns= ['X','count', 'Y']

# Numbers of passses btween players
pass_between= DF.groupby(['player', 'pass_recipient']).id.count().reset_index()
pass_between.rename({'id': 'number_of_passes'}, axis=1, inplace=True)

# Merge the 2 dataframes to get average location starting and ending location of passes
pass_between = pass_between.merge(avg_locations, on='player')
pass_between = pass_between.merge(avg_locations, left_on='pass_recipient', right_index=True, suffixes=['', '_end'])
"pass_between.head()
# Out:
#                             player  pass_recipient  number_of_passes  \
# 0              Alexis Mac Allister  Enzo Fernandez                 6
# 7          Cristian Gabriel Romero  Enzo Fernandez                 7
# 15        Damián Emiliano Martínez  Enzo Fernandez                 1
# 29                  Julián Álvarez  Enzo Fernandez                 3
# 35  Lionel Andrés Messi Cuccittini  Enzo Fernandez                 2
#
#             X  count          Y     X_end  count_end      Y_end
# 0   68.737500     24  23.845833  56.77561         41  35.821951
# 7   33.905128     39  53.346154  56.77561         41  35.821951
# 15  12.641667     12  43.966667  56.77561         41  35.821951
# 29  76.346154     13  37.538462  56.77561         41  35.821951
# 35  71.588889     27  51.096296  56.77561         41  35.821951

# %% [markdown]
# Basic plotting

# %%
# Plotting
fig, ax = pitch.draw()

pass_lines = pitch.lines(pass_between.X, pass_between.Y,
                        pass_between.X_end, pass_between.Y_end,
                        color='Grey', zorder=.1, ax=ax, alpha= .2)

pass_nodes = pitch.scatter(avg_locations.X, avg_locations.Y,
                        color='#8B0000', linewidth=8, alpha=1, ax=ax)
